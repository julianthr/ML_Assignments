# %%
import commons
import pandas as pd

# %%
input_file = '../data/autotagging_genre.tsv'
tracks, tags, extra = commons.read_file(input_file)
# Out:
# Reading: 55215 tracks, 11199 albums, 3547 artists

# %%
tracks
# Out:
# {214: {'artist_id': 14,
#   'album_id': 31,
#   'path': '14/214.mp3',
#   'duration': 124.6,
#   'tags': ['genre---punkrock'],
#   'genre': {'punkrock'},
#   'instrument': set(),
#   'mood/theme': set()},
#  215: {'artist_id': 14,
#   'album_id': 31,
#   'path': '15/215.mp3',
#   'duration': 151.4,
#   'tags': ['genre---metal'],
#   'genre': {'metal'},
#   'instrument': set(),
#   'mood/theme': set()},
#  216: {'artist_id': 14,
#   'album_id': 31,
#   'path': '16/216.mp3',
#   'duration': 234.9,
#   'tags': ['genre---metal'],
#   'genre': {'metal'},
#   'instrument': set(),
#   'mood/theme': set()},
#  217: {'artist_id': 14,
#   'album_id': 31,
#   'path': '17/217.mp3',
#   'duration': 127.9,
#   'tags': ['genre---punkrock'],
#   'genre': {'punkrock'},
#   'instrument': set(),
#   'mood/theme': set()},
#  218: {'artist_id': 14,
#   'album_id': 31,
#   'path': '18/218.mp3',
#   'duration': 180.7,
#   'tags': ['genre---punkrock'],
#   'genre': {'punkrock'},
#   'instrument': set(),
# ...
